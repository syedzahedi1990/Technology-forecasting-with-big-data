# %%
from __future__ import annotations
import datetime as dt
import json, math, os, warnings
from pathlib import Path
from typing import Dict, List, Optional, Tuple
import copy


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

try:
    import torch
    import torch.nn as nn
    import torch.optim as optim
except ImportError:
    print("Error: PyTorch not installed. The script cannot run.")
    exit()


from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import t


pm = None; ETSModel = None; Holt = None; SimpleExpSmoothing = None
ConvergenceWarning = Warning; ValueWarning = Warning

try:
    from statsmodels.tsa.exponential_smoothing.ets import ETSModel
    from statsmodels.tsa.api import Holt, SimpleExpSmoothing
    from statsmodels.tools.sm_exceptions import ConvergenceWarning, ValueWarning
except ImportError:
    print("Warning: statsmodels not fully installed or outdated.")

try:
    import pmdarima as pm
except (ImportError, ValueError) as e:
    print(f"\nWarning: Failed to import pmdarima. Auto-ARIMA baseline will be skipped.")
    pm = None

mrmr = None
try:
    import mrmr
except ImportError:
    print("Warning: mrmr-selection not installed. Multivariate mode will fail if used.")

try:
    import optuna
    from optuna.samplers import TPESampler
    from optuna.pruners import SuccessiveHalvingPruner
except ImportError:
    print("Error: Optuna not installed. The script cannot run.")
    exit()

FUTURE_EXOG_POLICY = "persist"
# ---------- Configuration ----------
ROOT = Path("/yourpath")
BASE_OUT = GDRIVE_ROOT / "36_forecast_outputs_transformer_rec_hstepopt"
BASE_OUT.mkdir(parents=True, exist_ok=True)
STORAGE = f"sqlite:///{BASE_OUT / 'transformer_rechstepopt_rigorous_study.db'}"
MODEL_TYPE = "Transformer_RecHStepOpt"


FORECAST_HORIZON = 36; SEASONAL_PERIOD = 12


OPTUNA_N_TRIALS = 50 
MAX_EPOCHS_OPTUNA = 30
PATIENCE_ES = 5; N_CV_SPLITS = 5


MAX_EPOCHS_FINAL = 100 
WEIGHT_DECAY = 1e-4; RANDOM_STATE = 42

GRADIENT_CLIP_BPTT = 5.0



MC_SAMPLES_FOR_CI = 100; EPSILON = 1e-8


torch.manual_seed(RANDOM_STATE)
np.random.seed(RANDOM_STATE)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)


try:
    torch.backends.cudnn.benchmark = True
    if torch.cuda.is_available():
        if hasattr(torch.backends.cuda.matmul, 'allow_tf32'):
                torch.backends.cuda.matmul.allow_tf32 = True
        if hasattr(torch, 'set_float32_matmul_precision'):
            torch.set_float32_matmul_precision("medium")
except Exception:
    pass




class PositionalEncoding(nn.Module):
    """Standard sine/cosine positional encoding (batch_first)."""
    def __init__(self, d_model: int, max_len: int = 1000):
        super().__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)  
        self.register_buffer('pe', pe)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        
        L = x.size(1)
        return x + self.pe[:, :L, :]

class TransformerForecaster(nn.Module):
    
    def __init__(self, input_size: int, d_model: int, nhead: int,
                 num_layers: int, dim_feedforward: int, dropout: float):
        super().__init__()
        
        self.input_proj = nn.Linear(input_size, d_model)
        self.pos_enc = PositionalEncoding(d_model)

        enc_layer = nn.TransformerEncoderLayer(
            d_model=d_model, nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=dropout, batch_first=True  
        )
        self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)

        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(d_model, 1)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        
        h = self.input_proj(x)              
        h = self.pos_enc(h)                 
        h = self.encoder(h)                 
        h_last = h[:, -1, :]                
        h_last = self.dropout(h_last)
        out = self.fc(h_last)               
        return out

def build_model(hp: Dict, n_vars: int) -> nn.Module:
    d_model = int(hp["d_model"])
    nhead = int(hp["nhead"])
    dim_feedforward = int(d_model * hp["dim_feedforward_factor"])

    mdl = TransformerForecaster(
        input_size=n_vars,
        d_model=d_model,
        nhead=nhead,
        num_layers=int(hp["num_layers"]),
        dim_feedforward=dim_feedforward,
        dropout=float(hp["dropout_rate"]),
    ).to(device)

    try:
        if hasattr(torch, 'compile'):
            
            return mdl
        return mdl
    except Exception:
        return mdl


def smape_loss_np(y_true, y_pred, eps: float = EPSILON) -> float:
    y_true = np.asarray(y_true); y_pred = np.asarray(y_pred)
    num = np.abs(y_true - y_pred)
    den = (np.abs(y_true) + np.abs(y_pred) + eps) / 2.0
    return np.mean(num / den)

def calculate_metrics(y_true: np.ndarray, y_pred: np.ndarray, insample: Optional[np.ndarray] = None):
    if y_true.ndim == 1 or (y_true.ndim > 1 and y_true.shape[1] == 1):
        y_true = y_true.ravel(); y_pred = y_pred.ravel()

    smape = smape_loss_np(y_true, y_pred)
    mase = rmsse = np.nan

    if insample is not None and len(insample) > SEASONAL_PERIOD:
        s = SEASONAL_PERIOD
        seasonal_diff = insample[s:] - insample[:-s]        
        d = np.mean(np.abs(seasonal_diff))
        mae = np.mean(np.abs(y_true - y_pred))
        mse = np.mean((y_true - y_pred) ** 2)
        mase = mae / (d + EPSILON)
        denom_rmsse = np.mean(seasonal_diff ** 2)
        rmsse = np.sqrt(mse / (denom_rmsse + EPSILON))

    return {"SMAPE": smape, "MASE": mase, "RMSSE": rmsse}


def diebold_mariano_test(actuals: np.ndarray, pred1: np.ndarray, pred2: np.ndarray, horizon: int):
    
    actuals = actuals.ravel(); pred1 = pred1.ravel(); pred2 = pred2.ravel()
    if len(actuals) != len(pred1) or len(actuals) != len(pred2): return np.nan, np.nan
    N = len(actuals)
    if N == 0: return np.nan, np.nan

    loss1 = (actuals - pred1)**2; loss2 = (actuals - pred2)**2
    d = loss1 - loss2; d_mean = np.mean(d)

    q = horizon; gamma = np.zeros(q + 1)
    for k in range(q + 1):
        if k == 0: gamma[k] = np.var(d, ddof=0)
        else:
            try:
                cov = np.cov(d[k:], d[:N-k], ddof=0)
                if cov.ndim == 2: gamma[k] = cov[0, 1]
                else: gamma[k] = 0
            except Exception: gamma[k] = 0

    V = gamma[0] + 2 * np.sum([(1 - k/(q+1)) * gamma[k] for k in range(1, q+1)])

    if V <= 1e-9:
        if abs(d_mean) < 1e-9: return 0, 1.0
        else: return np.inf * np.sign(d_mean), 0.0

    DM_stat = d_mean / np.sqrt(V / N)
    p_value = 2 * (1 - t.cdf(np.abs(DM_stat), df=N-1))
    return DM_stat, p_value


def fit_smoother(series, method, alpha=None, beta=None):
    if method == "NS" or SimpleExpSmoothing is None or Holt is None: return None
    try:
        if method == "DES":
            return Holt(series, initialization_method="estimated").fit(smoothing_level=alpha, smoothing_trend=beta, optimized=False)
        if method == "ES":
             return SimpleExpSmoothing(series, initialization_method="estimated").fit(smoothing_level=alpha, optimized=False)
    except Exception: return None
    return None

def apply_fitted_smoother(fitter, df: pd.DataFrame, target: str) -> pd.DataFrame:
    if fitter is None: return df
    n = len(df); fitted_vals = fitter.fittedvalues
    if len(fitted_vals) == 0: return df

    
    if len(fitted_vals) == n: values = fitted_vals
    elif len(fitted_vals) < n:
       
        values = pd.concat([df[target].iloc[:n-len(fitted_vals)], fitted_vals])
    else: values = fitted_vals[:n]

    out = df.copy()
    if len(values) == n:
        
        out[target] = values.values
    else:
        
        return df

    out[target].bfill(inplace=True) 
    return out

def create_sequences_LplusH(df_in: pd.DataFrame, target: str,
                           features: List[str], num_lags: int, horizon: int) -> Tuple[np.ndarray, np.ndarray, np.ndarray, List[str]]:
    
    cols = [target] + features
    data = df_in[cols].values
    N = data.shape[0]

    X_input, Y_target, X_full = [], [], []

    
    for i in range(N - num_lags - horizon + 1):
        
        x_seq = data[i : i + num_lags]

        
        y_seq = data[i + num_lags : i + num_lags + horizon, 0]

        
        full_seq = data[i : i + num_lags + horizon]

        X_input.append(x_seq)
        Y_target.append(y_seq)
        X_full.append(full_seq)

    return np.array(X_input), np.array(Y_target), np.array(X_full), cols


def select_mrmr_features(df_window: pd.DataFrame, target: str, k: int, num_lags: int) -> List[str]:
    
    if k == 0 or mrmr is None: return []
    lagged = []; potential_features = [c for c in df_window.columns if c != target]
    if not potential_features: return []

    for col in [target] + potential_features:
        for l in range(1, num_lags + 1):
            lagged.append(df_window[col].shift(l).rename(f"{col}_lag_{l}"))

    df_lagged = pd.concat([df_window[[target]], *lagged], axis=1).dropna()
    if df_lagged.empty: return []

    X_cols = [c for c in df_lagged.columns if "_lag_" in c and not c.startswith(f"{target}_lag_")]
    if not X_cols: return []

    X = df_lagged[X_cols].ffill().fillna(0); y = df_lagged[target].values.ravel()
    K_eff = min(k, len(X_cols))

    try:
        selected_lagged = mrmr.mrmr_regression(X=X, y=y, K=K_eff)
        selected_base = list({s.split("_lag_")[0] for s in selected_lagged})
        return selected_base
    except Exception:
        return []


def mc_pred(model: nn.Module, inp: torch.Tensor, mc_samples: int):
    
    if mc_samples == 1:
        model.eval()
        with torch.no_grad():
            return model(inp).cpu().numpy()
    model.train() 
    with torch.no_grad():
        
        if inp.shape[0] == 1:
            inp_mc = inp.repeat(mc_samples, 1, 1)
        else:
            
            inp_mc = inp

        preds = model(inp_mc).cpu().numpy()
    return preds


def forecast_ets(series: pd.Series, horizon: int):
    if ETSModel is None: return np.full(horizon, np.nan)
    try:
        model = ETSModel(series, error="add", trend="add", seasonal="add",
                            damped_trend=True, seasonal_periods=SEASONAL_PERIOD)
        fit = model.fit(disp=False, optimized=True)
        forecast = fit.forecast(horizon)
        return np.asarray(forecast)
    except Exception:
        
        return np.repeat(series.iloc[-1] if not series.empty else 0, horizon)

def forecast_arima(series: pd.Series, horizon: int):
    
    if pm is None: return np.full(horizon, np.nan)
    try:
        model = pm.auto_arima(series, start_p=1, start_q=1, max_p=5, max_q=5, m=SEASONAL_PERIOD,
                                start_P=0, seasonal=True, d=None, D=1, trace=False,
                                error_action='ignore', suppress_warnings=True, stepwise=True)
        forecast = model.predict(n_periods=horizon)
        return np.asarray(forecast)
    except Exception: return np.full(horizon, np.nan)


def forecast_exogenous_variables(df_hist: pd.DataFrame, features: List[str], horizon: int) -> Dict[str, np.ndarray]:
    
    forecasts = {}
    for feat in features:
        forecasts[feat] = forecast_ets(df_hist[feat], horizon)
    return forecasts



def make_objective(tgt: str, train_val_df: pd.DataFrame,
                   k: int, mode: str):

    
    tscv = TimeSeriesSplit(n_splits=N_CV_SPLITS, test_size=FORECAST_HORIZON)

    def objective(trial: optuna.Trial):
        
        d_model = trial.suggest_categorical("d_model", [64, 128, 256, 512])
        
        
        possible_heads = [h for h in [4, 8, 16] if d_model >= h and d_model % h == 0]
        if not possible_heads:
            return float("inf")
        nhead = trial.suggest_categorical("nhead", possible_heads)
        
        dim_feedforward_factor = trial.suggest_categorical("dim_feedforward_factor", [2, 4])
        
        hp = {
            "d_model": d_model,
            "nhead": nhead,
            "num_layers": trial.suggest_int("num_layers", 1, 3),
            "dim_feedforward_factor": dim_feedforward_factor,
            "dropout_rate": trial.suggest_float("dropout_rate", 0.1, 0.5, step=0.1),
            
            "lr": trial.suggest_categorical("lr", [5e-5, 1e-4, 5e-4]),
            "batch_size": trial.suggest_categorical("batch_size", [32, 64, 128]), 
            "n_lags": trial.suggest_int("n_lags", SEASONAL_PERIOD, SEASONAL_PERIOD * 4, step=SEASONAL_PERIOD),
            "smoothing_method": trial.suggest_categorical("smoothing_method", ["NS", "ES", "DES"]),
            "smoothing_alpha": trial.suggest_float("smoothing_alpha", 0.1, 0.6),
            "smoothing_beta": trial.suggest_float("smoothing_beta", 0.05, 0.6),
        }

        n_lags = hp["n_lags"]
        smapes_cv = []

        
        for tr_idx, val_idx in tscv.split(train_val_df):
            
            if len(tr_idx) < n_lags + FORECAST_HORIZON:
                continue

            df_tr = train_val_df.iloc[tr_idx]
            
            Y_va_target = train_val_df.iloc[val_idx][tgt].values.ravel()


            
            smoother = fit_smoother(df_tr[tgt], hp["smoothing_method"], hp["smoothing_alpha"], hp["smoothing_beta"])
            df_tr_sm = apply_fitted_smoother(smoother, df_tr, tgt)

            
            if mode == "MULTI":
                base_feats = select_mrmr_features(df_tr_sm, tgt, k, num_lags=SEASONAL_PERIOD)
            else:
                base_feats = []
            n_vars = len([tgt, *base_feats])

            
            X_tr_in, Y_tr_tgt, X_tr_full, _ = create_sequences_LplusH(df_tr_sm, tgt, base_feats, n_lags, FORECAST_HORIZON)

            if X_tr_in.shape[0] == 0:
                continue

            
            
            X_tr_full_reshaped = X_tr_full.reshape(-1, n_vars)
            
            Y_target_for_scaling = X_tr_full[:, :, 0].reshape(-1, 1)


            sc_X = MinMaxScaler().fit(X_tr_full_reshaped)
            sc_y = MinMaxScaler().fit(Y_target_for_scaling)

            
            X_tr_in_s = sc_X.transform(X_tr_in.reshape(-1, n_vars)).reshape(X_tr_in.shape)
            X_tr_full_s = sc_X.transform(X_tr_full.reshape(-1, n_vars)).reshape(X_tr_full.shape)
            
            


            
            Xtr_in_t = torch.tensor(X_tr_in_s, dtype=torch.float32)
            Ytr_tgt_t = torch.tensor(Y_tr_tgt_s, dtype=torch.float32)
            Xtr_full_t = torch.tensor(X_tr_full_s, dtype=torch.float32)

            dl = torch.utils.data.DataLoader(
                torch.utils.data.TensorDataset(Xtr_in_t, Ytr_tgt_t, Xtr_full_t),
                batch_size=hp["batch_size"], shuffle=True)

            
            mdl = build_model(hp, n_vars)
            
            crit = nn.L1Loss()
            opt = optim.AdamW(mdl.parameters(), lr=hp["lr"], weight_decay=WEIGHT_DECAY)

            best_fold_smape = float("inf")
            no_imp = 0

            
            for ep in range(MAX_EPOCHS_OPTUNA):
                mdl.train()
                for X_in_b, Y_tgt_b, X_full_b in dl:
                    X_in_b, Y_tgt_b, X_full_b = X_in_b.to(device), Y_tgt_b.to(device), X_full_b.to(device)
                    opt.zero_grad(set_to_none=True)

                    
                    current_input = X_in_b 
                    recursive_preds = []

                    
                    with torch.autocast(device.type, enabled=(device.type == "cuda")):
                        for h in range(FORECAST_HORIZON):
                            
                            pred_h = mdl(current_input) 
                            recursive_preds.append(pred_h)

                            
                            if h < FORECAST_HORIZON - 1:
                                
                                new_point = _append_next_point(current_input, pred_h, n_vars, FUTURE_EXOG_POLICY)
                                current_input = torch.cat([current_input[:, 1:, :], new_point], dim=1)

                        
                        preds_H = torch.cat(recursive_preds, dim=1) 
                        loss = crit(preds_H, Y_tgt_b)
                    

                    if torch.isnan(loss): return float("inf")

                    loss.backward() 
                    torch.nn.utils.clip_grad_norm_(mdl.parameters(), GRADIENT_CLIP_BPTT)
                    opt.step()

                
                mdl.eval()

                
                initial_input_data = df_tr_sm[[tgt] + base_feats].iloc[-n_lags:].values
                initial_input_scaled = sc_X.transform(initial_input_data.reshape(-1, n_vars)).reshape(1, n_lags, n_vars)
                current_input_t_va = torch.tensor(initial_input_scaled, dtype=torch.float32, device=device)


                
                
                recursive_forecast_scaled_va = []

                
                with torch.no_grad():
                    for h in range(FORECAST_HORIZON):
                        pred_scaled_va = mdl(current_input_t_va)
                        recursive_forecast_scaled_va.append(pred_scaled_va.item())

                        if h < FORECAST_HORIZON - 1:
                            new_point_t_va = _append_next_point(current_input_t_va, pred_scaled_va, n_vars, FUTURE_EXOG_POLICY)
                            current_input_t_va = torch.cat([current_input_t_va[:, 1:, :], new_point_t_va], dim=1)
                
                preds_inv_va = sc_y.inverse_transform(np.array(recursive_forecast_scaled_va).reshape(-1, 1)).ravel()
                s = smape_loss_np(Y_va_target, preds_inv_va)

                
                trial.report(s, ep)
                if trial.should_prune():
                    raise optuna.TrialPruned()

                
                if s < best_fold_smape - 1e-5:
                    best_fold_smape = s; no_imp = 0
                else:
                    no_imp += 1

                if no_imp >= PATIENCE_ES:
                    break

            smapes_cv.append(best_fold_smape)

        if not smapes_cv:
            return float("inf")

        
        return float(np.mean(smapes_cv))

    return objective


def train_final_model_BPTT(hp: Dict, df_train: pd.DataFrame, tgt: str, base_feats: List[str], use_early_stopping: bool = True):
    
    n_lags = hp["n_lags"]
    n_vars = len([tgt, *base_feats])

    
    smoother = fit_smoother(df_train[tgt], hp.get("smoothing_method", "NS"), hp.get("smoothing_alpha"), hp.get("smoothing_beta"))
    df_train_sm = apply_fitted_smoother(smoother, df_train, tgt)

    
    X_in, Y_tgt, X_full, _ = create_sequences_LplusH(df_train_sm, tgt, base_feats, n_lags, FORECAST_HORIZON)

    if X_in.shape[0] == 0: return None, None, None

    
    if use_early_stopping and X_in.shape[0] > 10:
         split_idx = int(X_in.shape[0] * 0.8)
         X_tr_in, Y_tr_tgt, X_tr_full = X_in[:split_idx], Y_tgt[:split_idx], X_full[:split_idx]
         X_va_in, Y_va_tgt, X_va_full = X_in[split_idx:], Y_tgt[split_idx:], X_full[split_idx:]
    else:
        X_tr_in, Y_tr_tgt, X_tr_full = X_in, Y_tgt, X_full
        X_va_in = None

    
    X_tr_full_reshaped = X_tr_full.reshape(-1, n_vars)
    Y_target_for_scaling = X_tr_full[:, :, 0].reshape(-1, 1)

    sc_X = MinMaxScaler().fit(X_tr_full_reshaped)
    sc_y = MinMaxScaler().fit(Y_target_for_scaling)

    
    X_tr_in_s = sc_X.transform(X_tr_in.reshape(-1, n_vars)).reshape(X_tr_in.shape)
    X_tr_full_s = sc_X.transform(X_tr_full.reshape(-1, n_vars)).reshape(X_tr_full.shape)
    
    Y_tr_tgt_s = X_tr_full_s[:, n_lags:, 0]


    
    Xtr_in_t = torch.tensor(X_tr_in_s, dtype=torch.float32)
    Ytr_tgt_t = torch.tensor(Y_tr_tgt_s, dtype=torch.float32)
    Xtr_full_t = torch.tensor(X_tr_full_s, dtype=torch.float32)

    dl = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(Xtr_in_t, Ytr_tgt_t, Xtr_full_t),
        batch_size=hp["batch_size"], shuffle=True)

    
    if X_va_in is not None:
        X_va_in_s = sc_X.transform(X_va_in.reshape(-1, n_vars)).reshape(X_va_in.shape)
        X_va_full_s = sc_X.transform(X_va_full.reshape(-1, n_vars)).reshape(X_va_full.shape)
        Y_va_tgt_s = X_va_full_s[:, n_lags:, 0]

        Xva_in_t = torch.tensor(X_va_in_s, dtype=torch.float32).to(device)
        Yva_tgt_t = torch.tensor(Y_va_tgt_s, dtype=torch.float32).to(device)
        Xva_full_t = torch.tensor(X_va_full_s, dtype=torch.float32).to(device)
    else:
        Xva_in_t = None

    
    mdl = build_model(hp, n_vars)
    crit = nn.L1Loss()
    opt = optim.AdamW(mdl.parameters(), lr=hp["lr"], weight_decay=WEIGHT_DECAY)

    
    best_val_loss = float("inf"); no_imp = 0; best_model_state = None

    if Xva_in_t is None:
        
         best_model_state = copy.deepcopy(mdl.state_dict())

    for ep in range(MAX_EPOCHS_FINAL):
        mdl.train()
        
        for X_in_b, Y_tgt_b, X_full_b in dl:
            X_in_b, Y_tgt_b, X_full_b = X_in_b.to(device), Y_tgt_b.to(device), X_full_b.to(device)
            opt.zero_grad(set_to_none=True)

            current_input = X_in_b
            recursive_preds = []

            with torch.autocast(device.type, enabled=(device.type == "cuda")):
                for h in range(FORECAST_HORIZON):
                    pred_h = mdl(current_input)
                    recursive_preds.append(pred_h)

                    if h < FORECAST_HORIZON - 1:
                        new_point = _append_next_point(current_input, pred_h, n_vars, FUTURE_EXOG_POLICY)
                        current_input = torch.cat([current_input[:, 1:, :], new_point], dim=1)

                preds_H = torch.cat(recursive_preds, dim=1)
                loss = crit(preds_H, Y_tgt_b)

            if torch.isnan(loss): return None, None, None

            loss.backward()
            torch.nn.utils.clip_grad_norm_(mdl.parameters(), GRADIENT_CLIP_BPTT)
            opt.step()
        
        if Xva_in_t is not None:
            mdl.eval()
            with torch.no_grad():
                 
                current_input_va = Xva_in_t
                recursive_preds_va = []

                with torch.autocast(device.type, enabled=(device.type == "cuda")):
                    for h in range(FORECAST_HORIZON):
                        pred_h_va = mdl(current_input_va)
                        recursive_preds_va.append(pred_h_va)

                        if h < FORECAST_HORIZON - 1:
                            new_point_va = _append_next_point(current_input_va, pred_h_va, n_vars, FUTURE_EXOG_POLICY)
                            current_input_va = torch.cat([current_input_va[:, 1:, :], new_point_va], dim=1)

                    preds_H_va = torch.cat(recursive_preds_va, dim=1)
                    
                    val_loss = crit(preds_H_va, Yva_tgt_t).item()

            
            if val_loss < best_val_loss - 1e-5:
                best_val_loss = val_loss; no_imp = 0
                best_model_state = copy.deepcopy(mdl.state_dict())
            else:
                no_imp += 1

            if no_imp >= PATIENCE_ES:
                
                break
        

    if best_model_state:
         mdl.load_state_dict(best_model_state)

    return mdl, sc_X, sc_y


def run_hpo_pipeline(df_dev: pd.DataFrame, targets: List[str], k: int, mode: str) -> Dict:
    
    best_cfgs = {}
    print(f"\n--- Starting HPO Pipeline (Model: {MODEL_TYPE}, Mode: {mode}) ---")
    print("NOTE: This strategy (BPTT) is computationally intensive.")

    for tgt in targets:
        print(f"\nOptimizing Target: {tgt}")

        study_name = f"{MODEL_TYPE}_{mode}_{tgt}_HPO"
        try:
            study = optuna.create_study(
                study_name=study_name,
                direction="minimize", 
                sampler=TPESampler(seed=RANDOM_STATE),
                
                pruner=SuccessiveHalvingPruner(min_resource=3, reduction_factor=3),
                storage=STORAGE, load_if_exists=True)
        except Exception as e:
             print(f"Could not create/load Optuna study: {e}")
             continue

        
        if len(study.trials) < OPTUNA_N_TRIALS:
            objective_fn = make_objective(tgt, df_dev, k, mode)
            try:
                study.optimize(objective_fn,
                               n_trials=OPTUNA_N_TRIALS - len(study.trials),
                               n_jobs=1, 
                               show_progress_bar=True)
            except Exception as e:
                 print(f"Optuna optimization failed for {tgt}: {e}")
                 continue


        if study.best_trial is None:
            print(f"HPO failed for {tgt}. Skipping.")
            continue

        print(f"Best CV H-Step SMAPE for {tgt}: {study.best_value:.4f}")

        best_hp = study.best_params

        
        if mode == "MULTI":
            smoother = fit_smoother(df_dev[tgt],
                                    best_hp.get("smoothing_method", "NS"),
                                    best_hp.get("smoothing_alpha", 0.5),
                                    best_hp.get("smoothing_beta", 0.1))
            df_dev_sm = apply_fitted_smoother(smoother, df_dev, tgt)
            final_feats = select_mrmr_features(df_dev_sm, tgt, k, num_lags=SEASONAL_PERIOD)
        else:
            final_feats = []

        best_cfgs[tgt] = {
            "smape_dev_hstep": study.best_value,
            "hyperparams": best_hp,
            "base_features": final_feats,
            "n_vars_per_step": len([tgt, *final_feats]),
            "n_lags": best_hp["n_lags"]
        }

    return best_cfgs



def generate_forecast_recursive(
    df_hist: pd.DataFrame, target: str, cfg: Dict, horizon: int, mc_samples: int
):
    """
    Trains the model using BPTT and generates an H-step forecast recursively,
    WITHOUT using any future exogenous values (persist/none policy).
    Proper MC: one forward per step with batch=mc_samples and dropout active.
    """
    if not cfg or not cfg.get("hyperparams"):
        return None

    hp = cfg["hyperparams"]; feats = cfg.get("base_features", [])
    n_lags = int(cfg["n_lags"]); n_vars = int(cfg["n_vars_per_step"])

    
    mdl, sc_X, sc_y = train_final_model_BPTT(
        hp, df_hist, target, feats, use_early_stopping=True
    )
    if mdl is None:
        return None

    
    smoother = fit_smoother(
        df_hist[target],
        hp.get("smoothing_method", "NS"),
        hp.get("smoothing_alpha"),
        hp.get("smoothing_beta"),
    )
    df_hist_sm = apply_fitted_smoother(smoother, df_hist, target)
    init_block = df_hist_sm[[target] + feats].iloc[-n_lags:].values
    init_scaled = sc_X.transform(init_block.reshape(-1, n_vars)).reshape(1, n_lags, n_vars)

    
    use_mc = (mc_samples > 1) and (float(hp.get("dropout_rate", 0.0)) > 0.0)
    B = mc_samples if use_mc else 1

    current_input_t = torch.tensor(init_scaled, dtype=torch.float32, device=device)
    if use_mc:
        current_input_t = current_input_t.repeat(B, 1, 1)

    
    mdl.train() if use_mc else mdl.eval()

    preds_scaled = torch.zeros((B, horizon), device=device)

    
    with torch.no_grad():
        for h in range(horizon):
            pred_scaled = mdl(current_input_t).view(B)  # (B,)
            preds_scaled[:, h] = pred_scaled

            if h < horizon - 1:
                new_point_t = _append_next_point(
                    current_input_t, pred_scaled.view(B, 1), n_vars, FUTURE_EXOG_POLICY
                )
                current_input_t = torch.cat([current_input_t[:, 1:, :], new_point_t], dim=1)

    
    preds_np = preds_scaled.detach().cpu().numpy().reshape(-1, 1)
    preds_inv = sc_y.inverse_transform(preds_np).reshape(B, horizon)

    if use_mc:
        forecasts = np.median(preds_inv, axis=0)
        lowers   = np.percentile(preds_inv,  2.5, axis=0)
        uppers   = np.percentile(preds_inv, 97.5, axis=0)
    else:
        forecasts = preds_inv[0]
        lowers = np.full(horizon, np.nan); uppers = np.full(horizon, np.nan)

    forecasts = np.maximum(forecasts, 0)
    if use_mc:
        lowers = np.maximum(lowers, 0); uppers = np.maximum(uppers, 0)

    return pd.DataFrame({"Forecast": forecasts, "Lower_CI": lowers, "Upper_CI": uppers})



def plot_error_horizon_analysis(results_df: pd.DataFrame, model_type: str, output_dir: Path):
    # (Implementation identical to Strategy 2)
    ape_cols = [f'APE_H{h+1}' for h in range(FORECAST_HORIZON)]
    
    if results_df.empty: return
    if ape_cols[0] not in results_df.columns: return

    melted_df = pd.melt(results_df, id_vars=['Target', 'Model'], value_vars=ape_cols, var_name='Horizon', value_name='APE')
    melted_df['Horizon_Step'] = melted_df['Horizon'].str.replace('APE_H', '').astype(int)
    melted_df['SMAPE'] = melted_df['APE'] * 100

    plt.figure(figsize=(12, 6))
    sns.lineplot(data=melted_df, x='Horizon_Step', y='SMAPE', hue='Model', errorbar='sd')
    plt.title(f'Error Horizon Analysis (Including {model_type})')
    plt.xlabel('Forecast Horizon (Months)'); plt.ylabel('Average SMAPE (%)')
    plt.xticks(range(1, FORECAST_HORIZON + 1, 2)); plt.grid(True, linestyle='--', alpha=0.6)
    plt.legend(title='Model/Strategy'); plt.tight_layout()
    plot_path = output_dir / "error_horizon_analysis.png"
    plt.savefig(plot_path); plt.close()



if __name__ == "__main__":
    
    warnings.simplefilter("ignore", ConvergenceWarning)
    warnings.simplefilter("ignore", ValueWarning)
    warnings.simplefilter("ignore", UserWarning)
    if optuna:
        optuna.logging.set_verbosity(optuna.logging.WARNING)

    

    DF_PATH = ROOT / "data"

    
    if DF_PATH.exists():
        df_raw = pd.read_excel(DF_PATH)
    else:
      print("Data file not found. Proceeding with MOCK DATA for demonstration.")
      
      dates = pd.date_range(start="2010-01-01", periods=150, freq="M")
      
      time_index = np.arange(150)
      trend = time_index * 0.5
      seasonality = 50 * np.sin(time_index * (2 * np.pi / 12))
      noise = np.random.randn(150) * 10
      data = 100 + trend + seasonality + noise
      
      data_multi = np.tile(data, (5, 1)).T + np.random.randn(150, 5) * 5
      
      df_raw = pd.DataFrame(data_multi, columns=[f"var_{i} journal article" for i in range(5)])
      df_raw['Date'] = dates


    date_col = next((c for c in df_raw.columns
                     if c.lower().strip() == "date"), None)
    if date_col:
        df_raw[date_col] = pd.to_datetime(df_raw[date_col])
        df_raw.sort_values(date_col, inplace=True)
        df_raw.set_index(date_col, inplace=True)

    df_raw.columns = df_raw.columns.str.lower().str.strip()

    
    for col in df_raw.columns:
        if df_raw[col].dtype == "object":
             try:
                 df_raw[col] = pd.to_numeric(
                     df_raw[col].str.replace(r"[^\d.\-]", "", regex=True),
                     errors="coerce")
             except AttributeError:
                  df_raw[col] = pd.to_numeric(df_raw[col], errors="coerce")

    
    df_raw[df_raw < 0] = 0
    df_raw = df_raw.ffill().fillna(0)

    
    df_dev = df_raw.iloc[:-FORECAST_HORIZON].copy()
    df_test = df_raw.iloc[-FORECAST_HORIZON:].copy()

    if len(df_dev) < FORECAST_HORIZON * 3:
         print("Warning: Development set might be short for robust H-step optimization.")


    
    targets = [col for col in df_raw.columns if 'journal article' in col]
    if not targets:
         raise RuntimeError("No valid targets found in data.")


    
    K_FEATURES = 10
    best_cfgs_modes = {}

    
    for MODE in ["UNI", "MULTI"]:
        if MODE == "MULTI" and (mrmr is None or len(df_raw.columns) < 2):
            print(f"Skipping {MODE} mode."); continue

        
        best_cfgs = run_hpo_pipeline(df_dev, targets, k=K_FEATURES, mode=MODE)
        best_cfgs_modes[MODE] = best_cfgs

        
        best_path = BASE_OUT / f"best_hyperparameters_{MODE}.json"
        try:
            tmp = best_path.with_suffix(".tmp")
            with open(tmp, 'w') as f:
                json.dump(best_cfgs, f, indent=2)
            tmp.replace(best_path)
        except Exception as e:
            print(f"Could not save HPO results for {MODE}: {e}")

    
    print("\n--- Starting Test Set (Hold-out) Evaluation ---")
    evaluation_records = []; baseline_cache = {}

    for MODE in best_cfgs_modes.keys():
        best_cfgs = best_cfgs_modes[MODE]
        MODEL_MODE_NAME = f"{MODEL_TYPE}_{MODE}"

        for tgt in targets:
            print(f"\nEvaluating {MODEL_MODE_NAME} for: {tgt}")
            cfg = best_cfgs.get(tgt)
            if not cfg: continue

            
            fc_df = generate_forecast_recursive(df_dev, tgt, cfg, FORECAST_HORIZON, mc_samples=1)

            if fc_df is None:
                print(f"Skipping {tgt} ({MODE}) due to training failure."); continue

            y_true = df_test[tgt].values.ravel()
            y_pred_model = fc_df["Forecast"].values.ravel()
            insample_data = df_dev[tgt].values

            model_m = calculate_metrics(y_true, y_pred_model, insample_data)

            
            ape = np.abs(y_true - y_pred_model) / ((np.abs(y_true) + np.abs(y_pred_model) + EPSILON) / 2.0)
            ape_dict = {f'APE_H{h+1}': ape[h] for h in range(FORECAST_HORIZON)}

            record = {
                "Target": tgt, "Model": MODEL_MODE_NAME,
                **{f"{k}": v for k, v in model_m.items()},
                **ape_dict
            }

            
            if tgt not in baseline_cache:
                print(f"Calculating Baselines for {tgt}...")
                arima_pred = forecast_arima(df_dev[tgt], FORECAST_HORIZON)
                ets_pred = forecast_ets(df_dev[tgt], FORECAST_HORIZON)
                baseline_cache[tgt] = {"ARIMA": arima_pred, "ETS": ets_pred}

               
            for name, pred in baseline_cache[tgt].items():
                
                if not any(r['Target'] == tgt and r['Model'] == name for r in evaluation_records):
                    if np.isnan(pred).all():
                        metrics = {"SMAPE": np.nan, "MASE": np.nan, "RMSSE": np.nan}
                        ape_dict_base = {f'APE_H{h+1}': np.nan for h in range(FORECAST_HORIZON)}
                    else:
                        metrics = calculate_metrics(y_true, pred, insample_data)
                        ape_base = np.abs(y_true - pred) / ((np.abs(y_true) + np.abs(pred) + EPSILON) / 2.0)
                        ape_dict_base = {f'APE_H{h+1}': ape_base[h] for h in range(FORECAST_HORIZON)}

                    baseline_record = {
                        "Target": tgt, "Model": name,
                        **metrics,
                        **ape_dict_base
                    }
                    evaluation_records.append(baseline_record)

            # 3. Statistical Significance (Diebold-Mariano)
            # Retrieve baseline metrics for comparison
            arima_smape = next((r['SMAPE'] for r in evaluation_records if r['Target'] == tgt and r['Model'] == 'ARIMA'), np.inf)
            ets_smape = next((r['SMAPE'] for r in evaluation_records if r['Target'] == tgt and r['Model'] == 'ETS'), np.inf)

            if np.isnan(arima_smape): arima_smape = np.inf
            if np.isnan(ets_smape): ets_smape = np.inf

            best_stat_name = None
            if arima_smape != np.inf or ets_smape != np.inf:
                if arima_smape <= ets_smape:
                    best_stat_name = "ARIMA"; best_stat_pred = baseline_cache[tgt]["ARIMA"]
                else:
                    best_stat_name = "ETS"; best_stat_pred = baseline_cache[tgt]["ETS"]

            if best_stat_name:
                if np.isnan(y_pred_model).any() or np.isnan(best_stat_pred).any():
                    dm_stat, dm_p = np.nan, np.nan
                else:
                    dm_stat, dm_p = diebold_mariano_test(y_true, y_pred_model, best_stat_pred, FORECAST_HORIZON)

                record[f"DM_vs_{best_stat_name}_Stat"] = dm_stat
                record[f"DM_vs_{best_stat_name}_Pval"] = dm_p

            evaluation_records.append(record)


    # Consolidate and save test results
    df_results = pd.DataFrame(evaluation_records)

    if not df_results.empty:
        df_results.to_csv(BASE_OUT / "test_evaluation_detailed.csv", index=False)

        # Create a summary view (Pivot table)
        try:
            summary_metrics = ['SMAPE', 'MASE', 'RMSSE']
            dm_cols = [col for col in df_results.columns if col.startswith('DM_')]

            pivot_df = df_results.pivot_table(index='Target', columns='Model', values=summary_metrics + dm_cols)
            # Flatten multi-index columns
            pivot_df.columns = ['_'.join(col).strip() for col in pivot_df.columns.values]
            pivot_df.reset_index().to_csv(BASE_OUT / "test_evaluation_summary.csv", index=False)
            print("\nTest Evaluation Summary saved.")

        except Exception as e:
            print(f"Error creating summary pivot table: {e}")

        # ------------- Error Horizon Analysis -------------
        print("\n--- Performing Error Horizon Analysis ---")
        plot_error_horizon_analysis(df_results, MODEL_TYPE, BASE_OUT)


    # ------------- Long-Term Forecast (Future Projection) -------------
    print("\n--- Generating Final 36-Month Future Forecasts (using full data) ---")
    df_full = pd.concat([df_dev, df_test])

    for MODE, best_cfgs in best_cfgs_modes.items():
        for tgt in targets:
            cfg = best_cfgs.get(tgt)
            if not cfg: continue

            print(f"Projecting Future for {tgt} ({MODE})...")

            # Generate forecast with Confidence Intervals (Trained via BPTT, Forecasted Recursively)
            fc_df = generate_forecast_recursive(df_full, tgt, cfg, FORECAST_HORIZON, MC_SAMPLES_FOR_CI)

            if fc_df is None:
                continue

            # Save the forecast
            safe_name = "".join(c if c.isalnum() else "_" for c in tgt)
            fc_df.to_csv(BASE_OUT / f"forecast_future_36m_{MODE.lower()}_{safe_name}.csv", index=False)

    print(f"\nAll tasks finished successfully. Outputs are located at: {BASE_OUT}")
# Out:
# Using device: cuda
#
# --- Starting HPO Pipeline (Model: Transformer_RecHStepOpt, Mode: UNI) ---
# NOTE: This strategy (BPTT) is computationally intensive.
#
# Optimizing Target: quantum computing journal article
#   0%|          | 0/50 [00:00<?, ?it/s]
# [W 2025-09-06 23:06:58,051] Trial 0 failed with parameters: {'d_model': 128, 'nhead': 4, 'dim_feedforward_factor': 2, 'num_layers': 3, 'dropout_rate': 0.1, 'lr': 5e-05, 'batch_size': 128, 'n_lags': 36, 'smoothing_method': 'DES', 'smoothing_alpha': 0.16974693032602092, 'smoothing_beta': 0.21067955669436994} because of the following error: NameError("name '_append_next_point' is not defined").
# Traceback (most recent call last):
#   File "/venv/main/lib/python3.12/site-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_6998/982233231.py", line 531, in objective
#     new_point = _append_next_point(current_input, pred_h, n_vars, FUTURE_EXOG_POLICY)
#                 ^^^^^^^^^^^^^^^^^^
# NameError: name '_append_next_point' is not defined
# [W 2025-09-06 23:06:58,056] Trial 0 failed with value None.
# Optuna optimization failed for quantum computing journal article: name '_append_next_point' is not defined
#
# Optimizing Target: generative ai journal article
#   0%|          | 0/50 [00:00<?, ?it/s]
# [W 2025-09-06 23:06:58,151] Trial 0 failed with parameters: {'d_model': 128, 'nhead': 4, 'dim_feedforward_factor': 2, 'num_layers': 3, 'dropout_rate': 0.1, 'lr': 5e-05, 'batch_size': 128, 'n_lags': 36, 'smoothing_method': 'DES', 'smoothing_alpha': 0.16974693032602092, 'smoothing_beta': 0.21067955669436994} because of the following error: NameError("name '_append_next_point' is not defined").
# Traceback (most recent call last):
#   File "/venv/main/lib/python3.12/site-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_6998/982233231.py", line 531, in objective
#     new_point = _append_next_point(current_input, pred_h, n_vars, FUTURE_EXOG_POLICY)
#                 ^^^^^^^^^^^^^^^^^^
# NameError: name '_append_next_point' is not defined
# [W 2025-09-06 23:06:58,155] Trial 0 failed with value None.
# Optuna optimization failed for generative ai journal article: name '_append_next_point' is not defined
#
# Optimizing Target: llm journal article
#   0%|          | 0/50 [00:00<?, ?it/s]
# [W 2025-09-06 23:06:58,243] Trial 0 failed with parameters: {'d_model': 128, 'nhead': 4, 'dim_feedforward_factor': 2, 'num_layers': 3, 'dropout_rate': 0.1, 'lr': 5e-05, 'batch_size': 128, 'n_lags': 36, 'smoothing_method': 'DES', 'smoothing_alpha': 0.16974693032602092, 'smoothing_beta': 0.21067955669436994} because of the following error: NameError("name '_append_next_point' is not defined").
# Traceback (most recent call last):
#   File "/venv/main/lib/python3.12/site-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_6998/982233231.py", line 531, in objective
#     new_point = _append_next_point(current_input, pred_h, n_vars, FUTURE_EXOG_POLICY)
#                 ^^^^^^^^^^^^^^^^^^
# NameError: name '_append_next_point' is not defined
# [W 2025-09-06 23:06:58,247] Trial 0 failed with value None.
# Optuna optimization failed for llm journal article: name '_append_next_point' is not defined
#
# Optimizing Target: autonomous vehicles journal article
#   0%|          | 0/50 [00:00<?, ?it/s]
# [W 2025-09-06 23:06:58,337] Trial 0 failed with parameters: {'d_model': 128, 'nhead': 4, 'dim_feedforward_factor': 2, 'num_layers': 3, 'dropout_rate': 0.1, 'lr': 5e-05, 'batch_size': 128, 'n_lags': 36, 'smoothing_method': 'DES', 'smoothing_alpha': 0.16974693032602092, 'smoothing_beta': 0.21067955669436994} because of the following error: NameError("name '_append_next_point' is not defined").
# Traceback (most recent call last):
#   File "/venv/main/lib/python3.12/site-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_6998/982233231.py", line 531, in objective
#     new_point = _append_next_point(current_input, pred_h, n_vars, FUTURE_EXOG_POLICY)
#                 ^^^^^^^^^^^^^^^^^^
# NameError: name '_append_next_point' is not defined
# [W 2025-09-06 23:06:58,341] Trial 0 failed with value None.
# Optuna optimization failed for autonomous vehicles journal article: name '_append_next_point' is not defined
#
# Optimizing Target: digital twins journal article
#   0%|          | 0/50 [00:00<?, ?it/s]
# [W 2025-09-06 23:06:58,431] Trial 0 failed with parameters: {'d_model': 128, 'nhead': 4, 'dim_feedforward_factor': 2, 'num_layers': 3, 'dropout_rate': 0.1, 'lr': 5e-05, 'batch_size': 128, 'n_lags': 36, 'smoothing_method': 'DES', 'smoothing_alpha': 0.16974693032602092, 'smoothing_beta': 0.21067955669436994} because of the following error: NameError("name '_append_next_point' is not defined").
# Traceback (most recent call last):
#   File "/venv/main/lib/python3.12/site-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_6998/982233231.py", line 531, in objective
#     new_point = _append_next_point(current_input, pred_h, n_vars, FUTURE_EXOG_POLICY)
#                 ^^^^^^^^^^^^^^^^^^
# NameError: name '_append_next_point' is not defined
# [W 2025-09-06 23:06:58,435] Trial 0 failed with value None.
# Optuna optimization failed for digital twins journal article: name '_append_next_point' is not defined
#
# Optimizing Target: next generation ai journal article
#   0%|          | 0/50 [00:00<?, ?it/s]
# [W 2025-09-06 23:06:58,525] Trial 0 failed with parameters: {'d_model': 128, 'nhead': 4, 'dim_feedforward_factor': 2, 'num_layers': 3, 'dropout_rate': 0.1, 'lr': 5e-05, 'batch_size': 128, 'n_lags': 36, 'smoothing_method': 'DES', 'smoothing_alpha': 0.16974693032602092, 'smoothing_beta': 0.21067955669436994} because of the following error: NameError("name '_append_next_point' is not defined").
# Traceback (most recent call last):
#   File "/venv/main/lib/python3.12/site-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_6998/982233231.py", line 531, in objective
#     new_point = _append_next_point(current_input, pred_h, n_vars, FUTURE_EXOG_POLICY)
#                 ^^^^^^^^^^^^^^^^^^
# NameError: name '_append_next_point' is not defined
# [W 2025-09-06 23:06:58,529] Trial 0 failed with value None.
# Optuna optimization failed for next generation ai journal article: name '_append_next_point' is not defined
#
# Optimizing Target: advances in cybersecurity journal article
#   0%|          | 0/50 [00:00<?, ?it/s]
# [W 2025-09-06 23:06:58,621] Trial 0 failed with parameters: {'d_model': 128, 'nhead': 4, 'dim_feedforward_factor': 2, 'num_layers': 3, 'dropout_rate': 0.1, 'lr': 5e-05, 'batch_size': 128, 'n_lags': 36, 'smoothing_method': 'DES', 'smoothing_alpha': 0.16974693032602092, 'smoothing_beta': 0.21067955669436994} because of the following error: NameError("name '_append_next_point' is not defined").
# Traceback (most recent call last):
#   File "/venv/main/lib/python3.12/site-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_6998/982233231.py", line 531, in objective
#     new_point = _append_next_point(current_input, pred_h, n_vars, FUTURE_EXOG_POLICY)
#                 ^^^^^^^^^^^^^^^^^^
# NameError: name '_append_next_point' is not defined
# [W 2025-09-06 23:06:58,624] Trial 0 failed with value None.
# Optuna optimization failed for advances in cybersecurity journal article: name '_append_next_point' is not defined
#
# Optimizing Target: misinformation journal article
#   0%|          | 0/50 [00:00<?, ?it/s]
# [W 2025-09-06 23:06:58,721] Trial 0 failed with parameters: {'d_model': 128, 'nhead': 4, 'dim_feedforward_factor': 2, 'num_layers': 3, 'dropout_rate': 0.1, 'lr': 5e-05, 'batch_size': 128, 'n_lags': 36, 'smoothing_method': 'DES', 'smoothing_alpha': 0.16974693032602092, 'smoothing_beta': 0.21067955669436994} because of the following error: NameError("name '_append_next_point' is not defined").
# Traceback (most recent call last):
#   File "/venv/main/lib/python3.12/site-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_6998/982233231.py", line 531, in objective
#     new_point = _append_next_point(current_input, pred_h, n_vars, FUTURE_EXOG_POLICY)
#                 ^^^^^^^^^^^^^^^^^^
# NameError: name '_append_next_point' is not defined
# [W 2025-09-06 23:06:58,725] Trial 0 failed with value None.
# Optuna optimization failed for misinformation journal article: name '_append_next_point' is not defined
#
# Optimizing Target: 3d printing journal article
#   0%|          | 0/50 [00:00<?, ?it/s]
# [W 2025-09-06 23:06:58,815] Trial 0 failed with parameters: {'d_model': 128, 'nhead': 4, 'dim_feedforward_factor': 2, 'num_layers': 3, 'dropout_rate': 0.1, 'lr': 5e-05, 'batch_size': 128, 'n_lags': 36, 'smoothing_method': 'DES', 'smoothing_alpha': 0.16974693032602092, 'smoothing_beta': 0.21067955669436994} because of the following error: NameError("name '_append_next_point' is not defined").
# Traceback (most recent call last):
#   File "/venv/main/lib/python3.12/site-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_6998/982233231.py", line 531, in objective
#     new_point = _append_next_point(current_input, pred_h, n_vars, FUTURE_EXOG_POLICY)
#                 ^^^^^^^^^^^^^^^^^^
# NameError: name '_append_next_point' is not defined
# [W 2025-09-06 23:06:58,819] Trial 0 failed with value None.
# Optuna optimization failed for 3d printing journal article: name '_append_next_point' is not defined
#
# Optimizing Target: new programming models journal article
#   0%|          | 0/50 [00:00<?, ?it/s]
# [W 2025-09-06 23:06:58,938] Trial 0 failed with parameters: {'d_model': 128, 'nhead': 4, 'dim_feedforward_factor': 2, 'num_layers': 3, 'dropout_rate': 0.1, 'lr': 5e-05, 'batch_size': 128, 'n_lags': 36, 'smoothing_method': 'DES', 'smoothing_alpha': 0.16974693032602092, 'smoothing_beta': 0.21067955669436994} because of the following error: NameError("name '_append_next_point' is not defined").
# Traceback (most recent call last):
#   File "/venv/main/lib/python3.12/site-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_6998/982233231.py", line 531, in objective
#     new_point = _append_next_point(current_input, pred_h, n_vars, FUTURE_EXOG_POLICY)
#                 ^^^^^^^^^^^^^^^^^^
# NameError: name '_append_next_point' is not defined
# [W 2025-09-06 23:06:58,941] Trial 0 failed with value None.
# Optuna optimization failed for new programming models journal article: name '_append_next_point' is not defined
#
# Optimizing Target: reliability journal article
#   0%|          | 0/50 [00:00<?, ?it/s]
# [W 2025-09-06 23:06:59,030] Trial 0 failed with parameters: {'d_model': 128, 'nhead': 4, 'dim_feedforward_factor': 2, 'num_layers': 3, 'dropout_rate': 0.1, 'lr': 5e-05, 'batch_size': 128, 'n_lags': 36, 'smoothing_method': 'DES', 'smoothing_alpha': 0.16974693032602092, 'smoothing_beta': 0.21067955669436994} because of the following error: NameError("name '_append_next_point' is not defined").
# Traceback (most recent call last):
#   File "/venv/main/lib/python3.12/site-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_6998/982233231.py", line 531, in objective
#     new_point = _append_next_point(current_input, pred_h, n_vars, FUTURE_EXOG_POLICY)
#                 ^^^^^^^^^^^^^^^^^^
# NameError: name '_append_next_point' is not defined
# [W 2025-09-06 23:06:59,034] Trial 0 failed with value None.
# Optuna optimization failed for reliability journal article: name '_append_next_point' is not defined
#
# Optimizing Target: renewable energy journal article
#   0%|          | 0/50 [00:00<?, ?it/s]
# [W 2025-09-06 23:06:59,125] Trial 0 failed with parameters: {'d_model': 128, 'nhead': 4, 'dim_feedforward_factor': 2, 'num_layers': 3, 'dropout_rate': 0.1, 'lr': 5e-05, 'batch_size': 128, 'n_lags': 36, 'smoothing_method': 'DES', 'smoothing_alpha': 0.16974693032602092, 'smoothing_beta': 0.21067955669436994} because of the following error: NameError("name '_append_next_point' is not defined").
# Traceback (most recent call last):
#   File "/venv/main/lib/python3.12/site-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_6998/982233231.py", line 531, in objective
#     new_point = _append_next_point(current_input, pred_h, n_vars, FUTURE_EXOG_POLICY)
#                 ^^^^^^^^^^^^^^^^^^
# NameError: name '_append_next_point' is not defined
# [W 2025-09-06 23:06:59,128] Trial 0 failed with value None.
# Optuna optimization failed for renewable energy journal article: name '_append_next_point' is not defined
#
# Optimizing Target: sustainable technologies journal article
#   0%|          | 0/50 [00:00<?, ?it/s]
# [W 2025-09-06 23:06:59,217] Trial 0 failed with parameters: {'d_model': 128, 'nhead': 4, 'dim_feedforward_factor': 2, 'num_layers': 3, 'dropout_rate': 0.1, 'lr': 5e-05, 'batch_size': 128, 'n_lags': 36, 'smoothing_method': 'DES', 'smoothing_alpha': 0.16974693032602092, 'smoothing_beta': 0.21067955669436994} because of the following error: NameError("name '_append_next_point' is not defined").
# Traceback (most recent call last):
#   File "/venv/main/lib/python3.12/site-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_6998/982233231.py", line 531, in objective
#     new_point = _append_next_point(current_input, pred_h, n_vars, FUTURE_EXOG_POLICY)
#                 ^^^^^^^^^^^^^^^^^^
# NameError: name '_append_next_point' is not defined
# [W 2025-09-06 23:06:59,221] Trial 0 failed with value None.
# Optuna optimization failed for sustainable technologies journal article: name '_append_next_point' is not defined
#
# Optimizing Target: generative agritech journal article
#   0%|          | 0/50 [00:00<?, ?it/s]
# [W 2025-09-06 23:06:59,540] Trial 0 failed with parameters: {'d_model': 128, 'nhead': 4, 'dim_feedforward_factor': 2, 'num_layers': 3, 'dropout_rate': 0.1, 'lr': 5e-05, 'batch_size': 128, 'n_lags': 36, 'smoothing_method': 'DES', 'smoothing_alpha': 0.16974693032602092, 'smoothing_beta': 0.21067955669436994} because of the following error: NameError("name '_append_next_point' is not defined").
# Traceback (most recent call last):
#   File "/venv/main/lib/python3.12/site-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_6998/982233231.py", line 531, in objective
#     new_point = _append_next_point(current_input, pred_h, n_vars, FUTURE_EXOG_POLICY)
#                 ^^^^^^^^^^^^^^^^^^
# NameError: name '_append_next_point' is not defined
# [W 2025-09-06 23:06:59,543] Trial 0 failed with value None.
# Optuna optimization failed for generative agritech journal article: name '_append_next_point' is not defined
#
# Optimizing Target: metaverse journal article
#   0%|          | 0/50 [00:00<?, ?it/s]
# [W 2025-09-06 23:06:59,679] Trial 0 failed with parameters: {'d_model': 128, 'nhead': 4, 'dim_feedforward_factor': 2, 'num_layers': 3, 'dropout_rate': 0.1, 'lr': 5e-05, 'batch_size': 128, 'n_lags': 36, 'smoothing_method': 'DES', 'smoothing_alpha': 0.16974693032602092, 'smoothing_beta': 0.21067955669436994} because of the following error: NameError("name '_append_next_point' is not defined").
# Traceback (most recent call last):
#   File "/venv/main/lib/python3.12/site-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_6998/982233231.py", line 531, in objective
#     new_point = _append_next_point(current_input, pred_h, n_vars, FUTURE_EXOG_POLICY)
#                 ^^^^^^^^^^^^^^^^^^
# NameError: name '_append_next_point' is not defined
# [W 2025-09-06 23:06:59,682] Trial 0 failed with value None.
# Optuna optimization failed for metaverse journal article: name '_append_next_point' is not defined
#
# --- Starting HPO Pipeline (Model: Transformer_RecHStepOpt, Mode: MULTI) ---
# NOTE: This strategy (BPTT) is computationally intensive.
#
# Optimizing Target: quantum computing journal article
#   0%|          | 0/50 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "<frozen runpy>", line 189, in _run_module_as_main
# Traceback (most recent call last):
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 120, in <module>
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 120, in <module>
# Traceback (most recent call last):
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 120, in <module>
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 115, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 120, in <module>
# Traceback (most recent call last):
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 115, in <module>
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "<frozen runpy>", line 189, in _run_module_as_main
# Traceback (most recent call last):
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 116, in <module>
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 115, in <module>
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 120, in <module>
# Traceback (most recent call last):
#   File "<frozen runpy>", line 189, in _run_module_as_main
# Traceback (most recent call last):
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 115, in <module>
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 115, in <module>
# Traceback (most recent call last):
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 120, in <module>
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 120, in <module>
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 115, in <module>
# Traceback (most recent call last):
#   File "<frozen runpy>", line 189, in _run_module_as_main
# Traceback (most recent call last):
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 115, in <module>
#   File "<frozen runpy>", line 131, in _get_module_details
#   File "<frozen importlib.util>", line 100, in find_spec
#   File "<frozen importlib._bootstrap>", line 1262, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1532, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1506, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1638, in find_spec
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap_external>", line 161, in _path_isfile
#   File "<frozen importlib._bootstrap_external>", line 153, in _path_is_mode_type
#   File "<frozen importlib._bootstrap_external>", line 147, in _path_stat
#   File "<frozen runpy>", line 189, in _run_module_as_main
# Traceback (most recent call last):
# KeyboardInterrupt  File "<frozen runpy>", line 112, in _get_module_details
#
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 115, in <module>
#   File "<frozen runpy>", line 189, in _run_module_as_main
# Traceback (most recent call last):
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 120, in <module>
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 115, in <module>
# Traceback (most recent call last):
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "<frozen runpy>", line 112, in _get_module_details
# Traceback (most recent call last):
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 115, in <module>
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 120, in <module>
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/venv/main/lib/python3.12/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 153, in <module>
# Traceback (most recent call last):
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 120, in <module>
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1091, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1190, in get_data
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 115, in <module>
# Traceback (most recent call last):
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 116, in <module>
# Traceback (most recent call last):
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 116, in <module>
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 120, in <module>
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 120, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 115, in <module>
# Traceback (most recent call last):
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 116, in <module>
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1091, in get_code
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap_external>", line 1191, in get_data
#   File "<frozen runpy>", line 189, in _run_module_as_main
# KeyboardInterrupt  File "<frozen runpy>", line 112, in _get_module_details
#
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 116, in <module>
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/venv/main/lib/python3.12/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 153, in <module>
# Traceback (most recent call last):
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "/venv/main/lib/python3.12/site-packages/joblib/__init__.py", line 120, in <module>
#     from .memory import MemorizedResult, Memory, expires_after, register_store_backend
#     from .memory import MemorizedResult, Memory, expires_after, register_store_backend
#             from .memory import MemorizedResult, Memory, expires_after, register_store_backend                from .memory import MemorizedResult, Memory, expires_after, register_store_backendfrom ._parallel_backends import ParallelBackendBase
# from .memory import MemorizedResult, Memory, expires_after, register_store_backend
#     from ._parallel_backends import ParallelBackendBasefrom .memory import MemorizedResult, Memory, expires_after, register_store_backendfrom ._parallel_backends import ParallelBackendBase
#
#
#         from .memory import MemorizedResult, Memory, expires_after, register_store_backend
#
# from .memory import MemorizedResult, Memory, expires_after, register_store_backend
#         from ._store_backends import StoreBackendBase      File "/venv/main/lib/python3.12/site-packages/joblib/memory.py", line 18, in <module>
# from .memory import MemorizedResult, Memory, expires_after, register_store_backend    from ._store_backends import StoreBackendBase  File "/venv/main/lib/python3.12/site-packages/joblib/memory.py", line 11, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/memory.py", line 11, in <module>
#     from ._parallel_backends import ParallelBackendBase    from ._parallel_backends import ParallelBackendBase
#   File "/venv/main/lib/python3.12/site-packages/joblib/_parallel_backends.py", line 21, in <module>
#
# from .memory import MemorizedResult, Memory, expires_after, register_store_backend        from ._store_backends import StoreBackendBase
#     from ._parallel_backends import ParallelBackendBase
# from ._parallel_backends import ParallelBackendBasefrom ._parallel_backends import ParallelBackendBase
#     from ._parallel_backends import ParallelBackendBase  File "/venv/main/lib/python3.12/site-packages/joblib/memory.py", line 33, in <module>
#
#   File "/venv/main/lib/python3.12/site-packages/joblib/_parallel_backends.py", line 21, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/_parallel_backends.py", line 21, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/memory.py", line 33, in <module>
# from .memory import MemorizedResult, Memory, expires_after, register_store_backend
#
# from .memory import MemorizedResult, Memory, expires_after, register_store_backend
#   File "/venv/main/lib/python3.12/site-packages/joblib/memory.py", line 33, in <module>
# from ._store_backends import StoreBackendBasefrom ._store_backends import StoreBackendBase
#
#   File "/venv/main/lib/python3.12/site-packages/joblib/memory.py", line 11, in <module>
#
# from ._parallel_backends import ParallelBackendBase
#
#
#
#   File "/venv/main/lib/python3.12/site-packages/joblib/memory.py", line 11, in <module>
#
# from .memory import MemorizedResult, Memory, expires_after, register_store_backend  File "/venv/main/lib/python3.12/site-packages/joblib/_store_backends.py", line 5, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/_parallel_backends.py", line 21, in <module>
#
#   File "/venv/main/lib/python3.12/site-packages/joblib/memory.py", line 18, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/_parallel_backends.py", line 21, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/_parallel_backends.py", line 21, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/_store_backends.py", line 21, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/memory.py", line 11, in <module>
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "/venv/main/lib/python3.12/site-packages/joblib/_parallel_backends.py", line 21, in <module>
#       File "/venv/main/lib/python3.12/site-packages/joblib/_store_backends.py", line 21, in <module>
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
# from ._parallel_backends import ParallelBackendBase  File "/venv/main/lib/python3.12/site-packages/joblib/_parallel_backends.py", line 21, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/memory.py", line 18, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/memory.py", line 11, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/_parallel_backends.py", line 21, in <module>
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#
#   File "/venv/main/lib/python3.12/site-packages/joblib/_store_backends.py", line 21, in <module>
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "/venv/main/lib/python3.12/site-packages/joblib/_parallel_backends.py", line 21, in <module>
#       File "<frozen importlib._bootstrap_external>", line 1091, in get_code
# from ._parallel_backends import ParallelBackendBase  File "<frozen importlib._bootstrap_external>", line 1190, in get_data
#   File "<frozen importlib._bootstrap>", line 1357, in _find_and_load
#
#   File "<frozen importlib._bootstrap>", line 418, in __enter__
# KeyboardInterrupt
#   File "<frozen importlib._bootstrap>", line 311, in acquire
#   File "<frozen importlib._bootstrap>", line 162, in __enter__
# KeyboardInterrupt
#   File "/venv/main/lib/python3.12/site-packages/joblib/_parallel_backends.py", line 21, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/_parallel_backends.py", line 21, in <module>
#     import argparse
# import argparse
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 1091, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1190, in get_data
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
# KeyboardInterrupt  File "<frozen importlib._bootstrap_external>", line 1091, in get_code
#
#   File "<frozen importlib._bootstrap_external>", line 1190, in get_data
# KeyboardInterrupt
#                 import pydocimport asyncioimport asyncio        import pydoc
#
#
#     import asyncioimport asyncio
#     from .func_inspect import (import asyncio
#
#
#     import pydoc
# from .func_inspect import (  File "/venv/main/lib/python3.12/asyncio/__init__.py", line 8, in <module>
#
#   File "/venv/main/lib/python3.12/pydoc.py", line 71, in <module>
#   File "/venv/main/lib/python3.12/asyncio/__init__.py", line 8, in <module>
# from .func_inspect import (
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#
#   File "/venv/main/lib/python3.12/pydoc.py", line 494, in <module>
#   File "<frozen importlib._bootstrap>", line 1322, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "/venv/main/lib/python3.12/asyncio/__init__.py", line 8, in <module>
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1262, in _find_spec
#   File "/venv/main/lib/python3.12/asyncio/__init__.py", line 8, in <module>
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 1322, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 1532, in find_spec
#   File "/venv/main/lib/python3.12/pydoc.py", line 71, in <module>
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap>", line 1262, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1506, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1532, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1091, in get_code
#       File "<frozen importlib._bootstrap_external>", line 1638, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1091, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1506, in _get_spec
# import asyncio  File "<frozen importlib._bootstrap_external>", line 1190, in get_data
#   File "<frozen importlib._bootstrap_external>", line 161, in _path_isfile
#
#   File "<frozen importlib._bootstrap_external>", line 1191, in get_data
#   File "<frozen importlib._bootstrap_external>", line 1624, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 153, in _path_is_mode_type
#   File "<frozen importlib._bootstrap_external>", line 161, in _path_isfile
# KeyboardInterrupt  File "<frozen importlib._bootstrap_external>", line 147, in _path_stat
# KeyboardInterrupt
#   File "<frozen importlib._bootstrap_external>", line 153, in _path_is_mode_type
#
#   File "<frozen importlib._bootstrap_external>", line 147, in _path_stat
# KeyboardInterrupt
#   File "/venv/main/lib/python3.12/asyncio/__init__.py", line 8, in <module>
# KeyboardInterrupt
#         from .executor import get_memmapping_executorfrom .executor import get_memmapping_executor
#
#     from .executor import get_memmapping_executorfrom .executor import get_memmapping_executorfrom .executor import get_memmapping_executor
#
#
# from .executor import get_memmapping_executorfrom .executor import get_memmapping_executor              File "/venv/main/lib/python3.12/site-packages/joblib/executor.py", line 11, in <module>
#     from .executor import get_memmapping_executor
#
# from .executor import get_memmapping_executorfrom .executor import get_memmapping_executor  File "/venv/main/lib/python3.12/site-packages/joblib/executor.py", line 11, in <module>
# from .executor import get_memmapping_executor
# from .executor import get_memmapping_executor
#   File "/venv/main/lib/python3.12/site-packages/joblib/executor.py", line 11, in <module>
#
#
#   File "/venv/main/lib/python3.12/site-packages/joblib/executor.py", line 11, in <module>
#
#   File "/venv/main/lib/python3.12/site-packages/joblib/executor.py", line 11, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/executor.py", line 11, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/executor.py", line 11, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/executor.py", line 11, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/executor.py", line 11, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/executor.py", line 11, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/executor.py", line 11, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/executor.py", line 11, in <module>
#         from .logger import format_timeimport json
#
#     from .logger import format_time
#       File "/venv/main/lib/python3.12/site-packages/joblib/logger.py", line 15, in <module>
# from .logger import format_time  File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "/venv/main/lib/python3.12/site-packages/joblib/logger.py", line 15, in <module>
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1091, in get_code
#   File "/venv/main/lib/python3.12/site-packages/joblib/logger.py", line 15, in <module>
#   File "<frozen importlib._bootstrap_external>", line 1190, in get_data
# KeyboardInterrupt
#         from .base_events import *from .base_events import *
#
# from .base_events import *
#   File "/venv/main/lib/python3.12/asyncio/base_events.py", line 40, in <module>
#   File "/venv/main/lib/python3.12/asyncio/base_events.py", line 45, in <module>
#   File "/venv/main/lib/python3.12/asyncio/base_events.py", line 34, in <module>
#     from .base_events import *
#   File "/venv/main/lib/python3.12/asyncio/base_events.py", line 34, in <module>
#     from .base_events import *
#   File "/venv/main/lib/python3.12/asyncio/base_events.py", line 40, in <module>
#         from . import staggeredfrom . import events
#
# import ssl
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "/venv/main/lib/python3.12/asyncio/events.py", line 26, in <module>
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 1322, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#       File "<frozen importlib._bootstrap>", line 1262, in _find_spec
# import ssl  File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#
#   File "<frozen importlib._bootstrap_external>", line 1532, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1091, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1506, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1191, in get_data
#   File "<frozen importlib._bootstrap_external>", line 1638, in find_spec
#   File "/venv/main/lib/python3.12/ssl.py", line 138, in <module>
# KeyboardInterrupt  File "<frozen importlib._bootstrap_external>", line 161, in _path_isfile
#
#   File "<frozen importlib._bootstrap_external>", line 153, in _path_is_mode_type
#   File "<frozen importlib._bootstrap_external>", line 147, in _path_stat
# KeyboardInterrupt
#     from . import events
#     from . import format_helpers  File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#
#   File "<frozen importlib._bootstrap>", line 1322, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 1262, in _find_spec
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap_external>", line 1532, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1506, in _get_spec
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 1638, in find_spec
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 161, in _path_isfile
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 153, in _path_is_mode_type
#   File "<frozen importlib._bootstrap_external>", line 1085, in get_code
#       File "<frozen importlib._bootstrap_external>", line 147, in _path_stat
# _IntEnum._convert_(  File "<frozen importlib._bootstrap_external>", line 1208, in path_stats
#
#   File "<frozen importlib._bootstrap_external>", line 147, in _path_stat
#   File "/venv/main/lib/python3.12/enum.py", line 948, in _convert_
# KeyboardInterrupt
# KeyboardInterrupt
#     import sysconfig
# import sysconfig
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 1128, in get_code
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 757, in _compile_bytecode
#   File "<frozen importlib._bootstrap_external>", line 1091, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1191, in get_data
# KeyboardInterrupt
# KeyboardInterrupt
#                     from ._memmapping_reducer import TemporaryResourcesManager, get_memmapping_reducersfrom ._memmapping_reducer import TemporaryResourcesManager, get_memmapping_reducersfrom ._memmapping_reducer import TemporaryResourcesManager, get_memmapping_reducers    from ._memmapping_reducer import TemporaryResourcesManager, get_memmapping_reducers
# from ._memmapping_reducer import TemporaryResourcesManager, get_memmapping_reducers
#
# from ._memmapping_reducer import TemporaryResourcesManager, get_memmapping_reducers
#
# from ._memmapping_reducer import TemporaryResourcesManager, get_memmapping_reducers    import pprint
#
# import pprint
#
#   File "/venv/main/lib/python3.12/site-packages/joblib/_memmapping_reducer.py", line 28, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/_memmapping_reducer.py", line 28, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/_memmapping_reducer.py", line 35, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/_memmapping_reducer.py", line 35, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/_memmapping_reducer.py", line 28, in <module>
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "/venv/main/lib/python3.12/site-packages/joblib/_memmapping_reducer.py", line 33, in <module>
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "/venv/main/lib/python3.12/site-packages/joblib/_memmapping_reducer.py", line 28, in <module>
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 1091, in get_code
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1190, in get_data
#   File "<frozen importlib._bootstrap_external>", line 1091, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1190, in get_data
# KeyboardInterrupt
# KeyboardInterrupt    from ._memmapping_reducer import TemporaryResourcesManager, get_memmapping_reducers
#
#     from ._memmapping_reducer import TemporaryResourcesManager, get_memmapping_reducers
#         from ._memmapping_reducer import TemporaryResourcesManager, get_memmapping_reducersfrom ._memmapping_reducer import TemporaryResourcesManager, get_memmapping_reducers
#
#   File "/venv/main/lib/python3.12/site-packages/joblib/_memmapping_reducer.py", line 35, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/_memmapping_reducer.py", line 28, in <module>
#       File "/venv/main/lib/python3.12/site-packages/joblib/_memmapping_reducer.py", line 28, in <module>
# import pprint  File "/venv/main/lib/python3.12/site-packages/joblib/_memmapping_reducer.py", line 35, in <module>
#
#     from ._memmapping_reducer import TemporaryResourcesManager, get_memmapping_reducers
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "/venv/main/lib/python3.12/site-packages/joblib/_memmapping_reducer.py", line 28, in <module>
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1091, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1190, in get_data
# KeyboardInterrupt
#     class Doc:
#   File "/venv/main/lib/python3.12/pydoc.py", line 524, in Doc
#     def getdocloc(self, object, basedir=sysconfig.get_path('stdlib')):
#                                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/venv/main/lib/python3.12/sysconfig.py", line 636, in get_path
#             from .externals.loky.backend import resource_trackerfrom .externals.loky.backend import resource_tracker
#
# from .backports import make_memmap
#                 import numpy as np    import numpy as npfrom .externals.loky.backend import resource_trackerimport numpy as np
# import numpy as np
#
#
#
# from .externals.loky.backend import resource_tracker
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "/venv/main/lib/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 47, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 47, in <module>
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "/venv/main/lib/python3.12/site-packages/numpy/__init__.py", line 157, in <module>
#   File "/venv/main/lib/python3.12/site-packages/numpy/__init__.py", line 157, in <module>
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "/venv/main/lib/python3.12/site-packages/numpy/__init__.py", line 157, in <module>
#   File "/venv/main/lib/python3.12/site-packages/numpy/__init__.py", line 159, in <module>
#   File "/venv/main/lib/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 47, in <module>
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "/venv/main/lib/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 51, in <module>
# ...
#   File "/venv/main/lib/python3.12/site-packages/numpy/random/_pickle.py", line 1, in <module>
#   File "bit_generator.pyx", line 40, in init numpy.random.bit_generator
#   File "bit_generator.pyx", line 40, in init numpy.random.bit_generator
#   File "/venv/main/lib/python3.12/secrets.py", line 17, in <module>
#   File "/venv/main/lib/python3.12/secrets.py", line 17, in <module>
#     from . import random
#   File "/venv/main/lib/python3.12/site-packages/numpy/random/__init__.py", line 180, in <module>
#     from .mtrand import RandomState
#   File "numpy/random/mtrand.pyx", line 1, in init numpy.random.mtrand
#   File "bit_generator.pyx", line 1, in init numpy.random.bit_generator
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#       File "<frozen importlib._bootstrap>", line 1322, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 1262, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1532, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1506, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1638, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 161, in _path_isfile
#   File "<frozen importlib._bootstrap_external>", line 153, in _path_is_mode_type
#   File "<frozen importlib._bootstrap_external>", line 147, in _path_stat
# KeyboardInterrupt
#     from hmac import compare_digest
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#       File "<frozen importlib._bootstrap>", line 1322, in _find_and_load_unlocked
# from hmac import compare_digest
#   File "<frozen importlib._bootstrap>", line 1262, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1532, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1506, in _get_spec
#   File "/venv/main/lib/python3.12/hmac.py", line 17, in <module>
#   File "<frozen importlib._bootstrap_external>", line 1605, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 147, in _path_stat
# KeyboardInterrupt
# from .mtrand import RandomState
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1322, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 1262, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1532, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1506, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1605, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 147, in _path_stat
# KeyboardInterrupt
#     from . import _pickle
#   File "/venv/main/lib/python3.12/site-packages/numpy/random/_pickle.py", line 1, in <module>
#     from . import core
#   File "/venv/main/lib/python3.12/site-packages/numpy/ma/core.py", line 2697, in <module>
#     import hashlib as _hashlib
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1085, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1208, in path_stats
#   File "<frozen importlib._bootstrap_external>", line 147, in _path_stat
# KeyboardInterrupt
#     from . import spawn    from .mtrand import RandomState
#   File "numpy/random/mtrand.pyx", line 1, in init numpy.random.mtrand
#   File "bit_generator.pyx", line 40, in init numpy.random.bit_generator
#   File "/venv/main/lib/python3.12/secrets.py", line 17, in <module>
#     from hmac import compare_digest
#   File "/venv/main/lib/python3.12/hmac.py", line 17, in <module>
#     import hashlib as _hashlib
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1091, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1191, in get_data
# KeyboardInterrupt
#
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1091, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1191, in get_data
# KeyboardInterrupt
#     class MaskedArray(ndarray):
#   File "/venv/main/lib/python3.12/site-packages/numpy/ma/core.py", line 6093, in MaskedArray
#     copy = _arraymethod('copy')
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/venv/main/lib/python3.12/site-packages/numpy/ma/core.py", line 2544, in _arraymethod
#     def _arraymethod(funcname, onmask=True):
#
# KeyboardInterrupt
# [W 2025-09-06 23:07:27,635] Trial 0 failed with parameters: {'d_model': 128, 'nhead': 4, 'dim_feedforward_factor': 2, 'num_layers': 3, 'dropout_rate': 0.1, 'lr': 5e-05, 'batch_size': 128, 'n_lags': 36, 'smoothing_method': 'DES', 'smoothing_alpha': 0.16974693032602092, 'smoothing_beta': 0.21067955669436994} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/venv/main/lib/python3.12/site-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_6998/982233231.py", line 458, in objective
#     base_feats = select_mrmr_features(df_tr_sm, tgt, k, num_lags=SEASONAL_PERIOD)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_6998/982233231.py", line 340, in select_mrmr_features
#     selected_lagged = mrmr.mrmr_regression(X=X, y=y, K=K_eff)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/venv/main/lib/python3.12/site-packages/mrmr/pandas.py", line 245, in mrmr_regression
#     return mrmr_base(K=K, relevance_func=relevance_func, redundancy_func=redundancy_func,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/venv/main/lib/python3.12/site-packages/mrmr/main.py", line 98, in mrmr_base
#     relevance = relevance_func(**relevance_args)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/venv/main/lib/python3.12/site-packages/mrmr/pandas.py", line 49, in f_regression
#     return parallel_df(_f_regression, X, y, n_jobs=n_jobs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/venv/main/lib/python3.12/site-packages/mrmr/pandas.py", line 17, in parallel_df
#     lst = Parallel(n_jobs=n_jobs)(
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/venv/main/lib/python3.12/site-packages/joblib/parallel.py", line 2072, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "/venv/main/lib/python3.12/site-packages/joblib/parallel.py", line 1682, in _get_outputs
#     yield from self._retrieve()
#   File "/venv/main/lib/python3.12/site-packages/joblib/parallel.py", line 1800, in _retrieve
#     time.sleep(0.01)
# KeyboardInterrupt
# [W 2025-09-06 23:07:27,639] Trial 0 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 998
#     995     print(f"Skipping {MODE} mode."); continue
#     997 # Run HPO (optimizing H-step SMAPE via BPTT training)
# --> 998 best_cfgs = run_hpo_pipeline(df_dev, targets, k=K_FEATURES, mode=MODE)
#     999 best_cfgs_modes[MODE] = best_cfgs
#    1001 # Save HPO results
#
# Cell In[1], line 772, in run_hpo_pipeline(df_dev, targets, k, mode)
#     770 objective_fn = make_objective(tgt, df_dev, k, mode)
#     771 try:
# --> 772     study.optimize(objective_fn,
#     773                    n_trials=OPTUNA_N_TRIALS - len(study.trials),
#     774                    n_jobs=1, # Keep n_jobs=1 for stability with PyTorch/GPU BPTT
#     775                    show_progress_bar=True)
#     776 except Exception as e:
#     777      print(f"Optuna optimization failed for {tgt}: {e}")
#
# File /venv/main/lib/python3.12/site-packages/optuna/study/study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)    397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File /venv/main/lib/python3.12/site-packages/optuna/study/_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File /venv/main/lib/python3.12/site-packages/optuna/study/_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial_id = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File /venv/main/lib/python3.12/site-packages/optuna/study/_optimize.py:258, in _run_trial(study, func, catch)
#     251         assert False, "Should not reach."
#     253 if (
#     254     updated_state == TrialState.FAIL
#     255     and func_err is not None
#     256     and not isinstance(func_err, catch)
#     257 ):
# --> 258     raise func_err
#     259 return trial._trial_id
#
# File /venv/main/lib/python3.12/site-packages/optuna/study/_optimize.py:201, in _run_trial(study, func, catch)
#     199 with get_heartbeat_thread(trial._trial_id, study._storage):
#     200     try:
# --> 201         value_or_values = func(trial)
#     202     except exceptions.TrialPruned as e:
#     203         # TODO(mamu): Handle multi-objective cases.
#     204         state = TrialState.PRUNED
#
# Cell In[1], line 458, in make_objective.<locals>.objective(trial)
#     456 # 2. Feature Selection (mRMR)
#     457 if mode == "MULTI":
# --> 458     base_feats = select_mrmr_features(df_tr_sm, tgt, k, num_lags=SEASONAL_PERIOD)
#     459 else:
#     460     base_feats = []
#
# Cell In[1], line 340, in select_mrmr_features(df_window, target, k, num_lags)
#     337 K_eff = min(k, len(X_cols))
#     339 try:
# --> 340     selected_lagged = mrmr.mrmr_regression(X=X, y=y, K=K_eff)
#     341     selected_base = list({s.split("_lag_")[0] for s in selected_lagged})
#     342     return selected_base
#
# File /venv/main/lib/python3.12/site-packages/mrmr/pandas.py:245, in mrmr_regression(X, y, K, relevance, redundancy, denominator, cat_features, cat_encoding, only_same_domain, return_scores, n_jobs, show_progress)
#     242 relevance_args = {'X': X, 'y': y}
#     243 redundancy_args = {'X': X}
# --> 245 return mrmr_base(K=K, relevance_func=relevance_func, redundancy_func=redundancy_func,
#     246                  relevance_args=relevance_args, redundancy_args=redundancy_args,
#     247                  denominator_func=denominator_func, only_same_domain=only_same_domain,
#     248                  return_scores=return_scores, show_progress=show_progress)
#
# File /venv/main/lib/python3.12/site-packages/mrmr/main.py:98, in mrmr_base(K, relevance_func, redundancy_func, relevance_args, redundancy_args, denominator_func, only_same_domain, return_scores, show_progress)
#      44 def mrmr_base(K, relevance_func, redundancy_func,
#      45               relevance_args={}, redundancy_args={},
#      46               denominator_func=np.mean, only_same_domain=False,
#      47               return_scores=False, show_progress=True):
#      48     """General function for mRMR algorithm.
#      49
#      50     Parameters
#    (...)     95         List of selected features.
#      96     """
# ---> 98     relevance = relevance_func(**relevance_args)
#      99     features = relevance[relevance.fillna(0) > 0].index.to_list()
#     100     relevance = relevance.loc[features]
#
# File /venv/main/lib/python3.12/site-packages/mrmr/pandas.py:49, in f_regression(X, y, n_jobs)
#      48 def f_regression(X, y, n_jobs):
# ---> 49     return parallel_df(_f_regression, X, y, n_jobs=n_jobs)
#
# File /venv/main/lib/python3.12/site-packages/mrmr/pandas.py:17, in parallel_df(func, df, series, n_jobs)
#      15 n_jobs = min(cpu_count(), len(df.columns)) if n_jobs == -1 else min(cpu_count(), n_jobs)
#      16 col_chunks = np.array_split(range(len(df.columns)), n_jobs)
# ---> 17 lst = Parallel(n_jobs=n_jobs)(
#      18     delayed(func)(df.iloc[:, col_chunk], series)
#      19     for col_chunk in col_chunks
#      20 )
#      21 return pd.concat(lst)
#
# File /venv/main/lib/python3.12/site-packages/joblib/parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File /venv/main/lib/python3.12/site-packages/joblib/parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File /venv/main/lib/python3.12/site-packages/joblib/parallel.py:1800, in Parallel._retrieve(self)
#    1789 if self.return_ordered:
#    1790     # Case ordered: wait for completion (or error) of the next job
#    1791     # that have been dispatched and not retrieved yet. If no job
#    (...)   1795     # control only have to be done on the amount of time the next
#    1796     # dispatched job is pending.
#    1797     if (nb_jobs == 0) or (
#    1798         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799     ):
# -> 1800         time.sleep(0.01)
#    1801         continue
#    1803 elif nb_jobs == 0:
#    1804     # Case unordered: jobs are added to the list of jobs to
#    1805     # retrieve `self._jobs` only once completed or in error, which
#    (...)   1811     # timeouts before any other dispatched job has completed and
#    1812     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:
